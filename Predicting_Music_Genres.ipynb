# %% [markdown]
# # Predicting Music Genres
#
# A colleague and I performed a decision tree classification analysis during my Master's Program. We used Spotify data obtained from the Spotify API. This data has various attributes such as tempo and popularity.

# %% [markdown]
# #### Note:
# I was proud of what I accomplished with this project but I would like to reproduce this analysis one day. Upon review, there are several things I would do differently in this analysis such as change the process of the data engineering for the project. Overall, this was a fun project to complete and review the results of this classification.

# %% [markdown]
# ## Load Libraries

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix,classification_report,precision_score

# %% [markdown]
# ## Load Data

# %%
df = pd.read_csv("SpotifyFeatures.csv")

# %% [markdown]
# ## Data Engineering
# When engineering the data, we chose these actions:
# * we decided to drop genres since the data included 27 genres. We simply chose the genres we were most interested in.
# * we combined genres based on our perceived knowledge of the genres. Generally, Rap and Hip-Hop have similarities so we paired the genres together.
# * Due to combining the genres, we had to drop duplicates on the track_ids within each newly labeled genre.
# * For simplicity, we dropped those track_ids that occurred multiple times with different genres.
#
# Once the data reflected the genres we were most interested in:
# * Categorical attributes were transformed into dummy columns for each value.

# %% [markdown]
# ### Creating the Data

# %%
drop_genres = ["A Capella","Anime","Children's Music","Movie","Comedy","Reggae",\
              "Ska","Soundtrack","World","Dance","Electronic", "Children’s Music"]
df2 = df[~(df["genre"].isin(drop_genres))]

# %%
Genre_dict = {"Pop":"Pop","Jazz":"Jazz/Blues","Blues":"Jazz/Blues","Country":"Country/Folk","Folk":"Country/Folk",
              "Rap":"Rap/Hip-Hop","Hip-Hop":"Rap/Hip-Hop","R&B":"R&B/Soul","Soul":"R&B/Soul",
              "Classical":"Classical/Opera", "Opera":"Classical/Opera","Rock":"Rock/Alt/Indie", "Alternative":"Rock/Alt/Indie",
              "Indie":"Rock/Alt/Indie","Reggaeton":"Reggaeton"}

# %%
for genre in df2.genre.unique():
    df2=df2.replace(genre,Genre_dict[genre])
    
df2.genre.value_counts()
# Out:
# Rock/Alt/Indie     28078
# Rap/Hip-Hop        18527
# Jazz/Blues         18464
# R&B/Soul           18081
# Country/Folk       17963
# Classical/Opera    17536
# Pop                 9386
# Reggaeton           8927
# Name: genre, dtype: int64

# %%
df3 = df2.drop_duplicates(subset=["genre","track_id"])
tracks = df3.track_id.value_counts().reset_index()
mulitple_ids = list(tracks[tracks.track_id>1]["index"])
df_Model = df3[~(df3.track_id.isin(mulitple_ids))]

# %% [markdown]
# ### Formatting Data for the Classification model

# %%
df_Model = df_Model.drop(columns=["artist_name","track_name","track_id"])

# %%
#make dummies for categorical
for i in range(len(df_Model.columns)):
    if df_Model[df_Model.columns[i]].dtypes == "O":
        if df_Model.columns[i]!="genre":
            dummy = pd.get_dummies(df_Model[df_Model.columns[i]], prefix = str(df_Model.columns[i]))
            df_Model = pd.concat([df_Model, dummy], axis = 1)

# %%
#drop unnecessary columns
df_Model=df_Model.drop(columns=['key','mode','time_signature'])

# %%
X = df_Model.drop(columns=['genre'])
y = df_Model['genre']

# %%
df_Model.iloc[:,0:12].describe()
# Out:
#          popularity  acousticness  danceability   duration_ms        energy  \
# count  82278.000000  82278.000000  82278.000000  8.227800e+04  82278.000000
# mean      40.053210      0.420040      0.540753  2.453812e+05      0.527367
# std       15.743149      0.370816      0.193743  1.180472e+05      0.278681
# min        0.000000      0.000001      0.058200  1.550900e+04      0.000020
# 25%       32.000000      0.063400      0.403000  1.878530e+05      0.297000
# 50%       42.000000      0.304000      0.559000  2.234930e+05      0.569000
# 75%       50.000000      0.827000      0.691000  2.721930e+05      0.760000
# max      100.000000      0.996000      0.987000  5.488000e+06      0.999000
#
#        instrumentalness      liveness      loudness   speechiness  \
# count      82278.000000  82278.000000  82278.000000  82278.000000
# mean           0.159602      0.193352    -10.555467      0.083809
# std            0.309763      0.166665      6.869715      0.089789
# min            0.000000      0.010200    -47.599000      0.022200
# 25%            0.000000      0.096100    -13.428750      0.036500
# 50%            0.000119      0.124000     -8.167000      0.047400
# 75%            0.068700      0.234000     -5.686000      0.083300
# max            0.994000      1.000000      3.744000      0.949000
#
#               tempo       valence
# count  82278.000000  82278.000000
# mean     116.498499      0.450418
# std       31.062070      0.261526
# min       34.151000      0.000000
# 25%       91.965000      0.228000
# 50%      112.950500      0.439000
# 75%      137.188750      0.661000
# max      242.903000      0.986000

# %% [markdown]
# ## Decision Tree Classification
# The final dataset was split 70/30 for a training set and a test set respectively.
#
# Four tests were performed for this analysis:
# * Stratified Sampling: The training/test sets were stratified based on the target value, genre.
# * Random Sampling: The training/test sets were randomly selected.
# * Feature Selection: Based on the variance within the data, several columns were chosen based on the variability calculated.
# * Set Parameters for Model: Same data set up as the first test, but parameters were added to the model. The maximum depths were 10 levels and the minimum amount of samples per leaf is 100.
#
# The best model was the last test performed. By setting those parameters for the decision model, it increased results for precision and recall for all genres.

# %% [markdown]
# ### Test 1: Stratified Sampling

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, stratify = y, random_state = 9)

# %%
Model = DecisionTreeClassifier()
Model.fit(X_train,y_train)
Predict = Model.predict(X_test)

print(classification_report(y_test,Predict))
# Out:
#                  precision    recall  f1-score   support
#
# Classical/Opera       0.89      0.90      0.90      5114
#    Country/Folk       0.47      0.46      0.47      3406
#      Jazz/Blues       0.60      0.59      0.59      4658
#             Pop       0.47      0.44      0.45       835
#        R&B/Soul       0.34      0.34      0.34      2843
#     Rap/Hip-Hop       0.58      0.55      0.56      1859
#       Reggaeton       0.60      0.65      0.63      2561
#  Rock/Alt/Indie       0.48      0.48      0.48      3408
#
#        accuracy                           0.59     24684
#       macro avg       0.55      0.55      0.55     24684
#    weighted avg       0.59      0.59      0.59     24684

# %%
Feat = list(Model.feature_importances_)
for i in range(len(list(X.columns))):
    print(X.columns[i], (100*Feat[i]))
# Out:
# popularity 15.730553122082513
# acousticness 20.036221151419877
# danceability 9.464209800003385
# duration_ms 5.424754884629846
# energy 6.159624858923034
# instrumentalness 7.779357447592285
# liveness 4.025358970813704
# loudness 6.693220539412597
# speechiness 8.393323867763296
# tempo 5.092938632891275
# valence 5.375230073484281
# key_A 0.37315371642105855
# key_A# 0.24998599599652577
# key_B 0.3318402837448929
# key_C 0.4469568579017878
# key_C# 0.3554809145471348
# key_D 0.31508779845158796
# key_D# 0.18385821036690628
# key_E 0.32305462825443626
# key_F 0.3979128276242854
# key_F# 0.3658317364648943
# key_G 0.3739689958184168
# key_G# 0.3562423811543125
# mode_Major 0.4455246533030264
# mode_Minor 0.8261847332509951
# time_signature_0/4 0.0
# time_signature_1/4 0.0196796111274612
# time_signature_3/4 0.20542861975229101
# time_signature_4/4 0.1701425234795997
# time_signature_5/4 0.08487216332427334

# %%
print("Number of levels: ", Model.get_depth())
print("Number of leaves: ", Model.get_n_leaves())
print("Parameters: ", Model.get_params())
# Out:
# Number of levels:  37
# Number of leaves:  13191
# Parameters:  {'ccp_alpha': 0.0, 'class_weight': None, 'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.0, 'min_impurity_split': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'presort': 'deprecated', 'random_state': None, 'splitter': 'best'}

# %% [markdown]
# ### Test 2: Random Sampling

# %%
X2_train, X2_test, y2_train, y2_test = train_test_split(X, y, test_size=0.3, random_state = 9)

# %%
Model2 = DecisionTreeClassifier()
Model2.fit(X2_train,y2_train)
Predict2 = Model2.predict(X2_test)

print(classification_report(y2_test,Predict2))
# Out:
#                  precision    recall  f1-score   support
#
# Classical/Opera       0.90      0.90      0.90      5108
#    Country/Folk       0.43      0.45      0.44      3385
#      Jazz/Blues       0.61      0.59      0.60      4613
#             Pop       0.45      0.47      0.46       828
#        R&B/Soul       0.34      0.32      0.33      2933
#     Rap/Hip-Hop       0.56      0.57      0.57      1844
#       Reggaeton       0.61      0.62      0.62      2535
#  Rock/Alt/Indie       0.46      0.47      0.46      3438
#
#        accuracy                           0.58     24684
#       macro avg       0.55      0.55      0.55     24684
#    weighted avg       0.58      0.58      0.58     24684

# %%
Feat2 = list(Model2.feature_importances_)
for i in range(len(list(X.columns))):
    print(X.columns[i], (100*Feat2[i]))
# Out:
# popularity 15.488655335512563
# acousticness 19.830359654140445
# danceability 9.770225327464379
# duration_ms 5.42258972349231
# energy 6.054167907939453
# instrumentalness 7.709026260836674
# liveness 4.111797013232579
# loudness 7.248277958888516
# speechiness 8.283691393711546
# tempo 4.876415317095565
# valence 5.376836885778197
# key_A 0.30040101616819104
# key_A# 0.3252654107043228
# key_B 0.3710365737667696
# key_C 0.3829408490865239
# key_C# 0.3360009511396342
# key_D 0.34450455867390767
# key_D# 0.20722760079493413
# key_E 0.3819088678959781
# key_F 0.3671074280225338
# key_F# 0.35358490239095813
# key_G 0.4446468186304299
# key_G# 0.29590356267113926
# mode_Major 0.5466287170356127
# mode_Minor 0.6648527784985548
# time_signature_0/4 0.0
# time_signature_1/4 0.030275952599622655
# time_signature_3/4 0.21075820659505642
# time_signature_4/4 0.20098834852787256
# time_signature_5/4 0.06392467870572753

# %%
#see tree in a text format
from sklearn.tree.export import export_text

r = export_text(Model2, feature_names=list(X.columns))
print(r)
# Out:
# |--- acousticness <= 0.87
# |   |--- popularity <= 39.50
# |   |   |--- instrumentalness <= 0.00
# |   |   |   |--- danceability <= 0.67
# |   |   |   |   |--- popularity <= 34.50
# |   |   |   |   |   |--- danceability <= 0.51
# |   |   |   |   |   |   |--- popularity <= 18.50
# |   |   |   |   |   |   |   |--- acousticness <= 0.63
# |   |   |   |   |   |   |   |   |--- popularity <= 0.50
# |   |   |   |   |   |   |   |   |   |--- danceability <= 0.30
# |   |   |   |   |   |   |   |   |   |   |--- class: Jazz/Blues
# |   |   |   |   |   |   |   |   |   |--- danceability >  0.30
# |   |   |   |   |   |   |   |   |   |   |--- class: Country/Folk
# |   |   |   |   |   |   |   |   |--- popularity >  0.50
# |   |   |   |   |   |   |   |   |   |--- popularity <= 6.00
# |   |   |   |   |   |   |   |   |   |   |--- loudness <= -6.02
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Jazz/Blues
# |   |   |   |   |   |   |   |   |   |   |--- loudness >  -6.02
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Rock/Alt/Indie
# |   |   |   |   |   |   |   |   |   |--- popularity >  6.00
# |   |   |   |   |   |   |   |   |   |   |--- instrumentalness <= 0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Reggaeton
# |   |   |   |   |   |   |   |   |   |   |--- instrumentalness >  0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |--- acousticness >  0.63
# |   |   |   |   |   |   |   |   |--- loudness <= -13.21
# |   |   |   |   |   |   |   |   |   |--- class: Classical/Opera
# |   |   |   |   |   |   |   |   |--- loudness >  -13.21
# |   |   |   |   |   |   |   |   |   |--- popularity <= 2.50
# |   |   |   |   |   |   |   |   |   |   |--- loudness <= -12.68
# |   |   |   |   |   |   |   |   |   |   |   |--- class: R&B/Soul
# |   |   |   |   |   |   |   |   |   |   |--- loudness >  -12.68
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Country/Folk
# |   |   |   |   |   |   |   |   |   |--- popularity >  2.50
# |   |   |   |   |   |   |   |   |   |   |--- speechiness <= 0.15
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- speechiness >  0.15
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |--- popularity >  18.50
# |   |   |   |   |   |   |   |--- valence <= 0.30
# |   |   |   |   |   |   |   |   |--- liveness <= 0.62
# |   |   |   |   |   |   |   |   |   |--- danceability <= 0.34
# |   |   |   |   |   |   |   |   |   |   |--- acousticness <= 0.61
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- acousticness >  0.61
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |--- danceability >  0.34
# |   |   |   |   |   |   |   |   |   |   |--- mode_Minor <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |   |--- mode_Minor >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |--- liveness >  0.62
# |   |   |   |   |   |   |   |   |   |--- energy <= 0.57
# |   |   |   |   |   |   |   |   |   |   |--- acousticness <= 0.81
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Jazz/Blues
# |   |   |   |   |   |   |   |   |   |   |--- acousticness >  0.81
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Classical/Opera
# |   |   |   |   |   |   |   |   |   |--- energy >  0.57
# |   |   |   |   |   |   |   |   |   |   |--- class: Reggaeton
# |   |   |   |   |   |   |   |--- valence >  0.30
# |   |   |   |   |   |   |   |   |--- speechiness <= 0.15
# |   |   |   |   |   |   |   |   |   |--- energy <= 0.95
# |   |   |   |   |   |   |   |   |   |   |--- popularity <= 25.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |   |--- popularity >  25.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 14
# |   |   |   |   |   |   |   |   |   |--- energy >  0.95
# |   |   |   |   |   |   |   |   |   |   |--- duration_ms <= 222860.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- duration_ms >  222860.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Classical/Opera
# |   |   |   |   |   |   |   |   |--- speechiness >  0.15
# |   |   |   |   |   |   |   |   |   |--- danceability <= 0.45
# |   |   |   |   |   |   |   |   |   |   |--- tempo <= 89.13
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- tempo >  89.13
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- danceability >  0.45
# |   |   |   |   |   |   |   |   |   |   |--- duration_ms <= 157705.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Jazz/Blues
# |   |   |   |   |   |   |   |   |   |   |--- duration_ms >  157705.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |--- danceability >  0.51
# |   |   |   |   |   |   |--- energy <= 0.62
# |   |   |   |   |   |   |   |--- energy <= 0.48
# |   |   |   |   |   |   |   |   |--- popularity <= 20.50
# |   |   |   |   |   |   |   |   |   |--- acousticness <= 0.76
# |   |   |   |   |   |   |   |   |   |   |--- valence <= 0.36
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- valence >  0.36
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- acousticness >  0.76
# |   |   |   |   |   |   |   |   |   |   |--- energy <= 0.40
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Classical/Opera
# |   |   |   |   |   |   |   |   |   |   |--- energy >  0.40
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Jazz/Blues
# |   |   |   |   |   |   |   |   |--- popularity >  20.50
# |   |   |   |   |   |   |   |   |   |--- popularity <= 33.50
# |   |   |   |   |   |   |   |   |   |   |--- valence <= 0.53
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |   |   |--- valence >  0.53
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |   |--- popularity >  33.50
# |   |   |   |   |   |   |   |   |   |   |--- acousticness <= 0.57
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Country/Folk
# |   |   |   |   |   |   |   |   |   |   |--- acousticness >  0.57
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |--- energy >  0.48
# |   |   |   |   |   |   |   |   |--- acousticness <= 0.60
# |   |   |   |   |   |   |   |   |   |--- speechiness <= 0.07
# |   |   |   |   |   |   |   |   |   |   |--- valence <= 0.40
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |   |--- valence >  0.40
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 12
# |   |   |   |   |   |   |   |   |   |--- speechiness >  0.07
# |   |   |   |   |   |   |   |   |   |   |--- energy <= 0.62
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |   |--- energy >  0.62
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Jazz/Blues
# |   |   |   |   |   |   |   |   |--- acousticness >  0.60
# |   |   |   |   |   |   |   |   |   |--- popularity <= 1.50
# |   |   |   |   |   |   |   |   |   |   |--- energy <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Country/Folk
# |   |   |   |   |   |   |   |   |   |   |--- energy >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: R&B/Soul
# |   |   |   |   |   |   |   |   |   |--- popularity >  1.50
# |   |   |   |   |   |   |   |   |   |   |--- popularity <= 33.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |   |--- popularity >  33.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |--- energy >  0.62
# |   |   |   |   |   |   |   |--- instrumentalness <= 0.00
# |   |   |   |   |   |   |   |   |--- popularity <= 5.00
# |   |   |   |   |   |   |   |   |   |--- duration_ms <= 230203.50
# |   |   |   |   |   |   |   |   |   |   |--- mode_Major <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- mode_Major >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Country/Folk
# |   |   |   |   |   |   |   |   |   |--- duration_ms >  230203.50
# |   |   |   |   |   |   |   |   |   |   |--- class: Jazz/Blues
# |   |   |   |   |   |   |   |   |--- popularity >  5.00
# |   |   |   |   |   |   |   |   |   |--- duration_ms <= 182847.00
# |   |   |   |   |   |   |   |   |   |   |--- acousticness <= 0.45
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |   |   |--- acousticness >  0.45
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- duration_ms >  182847.00
# |   |   |   |   |   |   |   |   |   |   |--- speechiness <= 0.04
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |   |--- speechiness >  0.04
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 16
# |   |   |   |   |   |   |   |--- instrumentalness >  0.00
# |   |   |   |   |   |   |   |   |--- danceability <= 0.60
# |   |   |   |   |   |   |   |   |   |--- instrumentalness <= 0.00
# |   |   |   |   |   |   |   |   |   |   |--- speechiness <= 0.11
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 10
# |   |   |   |   |   |   |   |   |   |   |--- speechiness >  0.11
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |--- instrumentalness >  0.00
# |   |   |   |   |   |   |   |   |   |   |--- loudness <= -2.38
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- loudness >  -2.38
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Rock/Alt/Indie
# |   |   |   |   |   |   |   |   |--- danceability >  0.60
# |   |   |   |   |   |   |   |   |   |--- speechiness <= 0.03
# |   |   |   |   |   |   |   |   |   |   |--- valence <= 0.76
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |   |--- valence >  0.76
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Jazz/Blues
# |   |   |   |   |   |   |   |   |   |--- speechiness >  0.03
# |   |   |   |   |   |   |   |   |   |   |--- tempo <= 164.96
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |   |--- tempo >  164.96
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Reggaeton
# |   |   |   |   |--- popularity >  34.50
# |   |   |   |   |   |--- speechiness <= 0.05
# |   |   |   |   |   |   |--- mode_Major <= 0.50
# |   |   |   |   |   |   |   |--- loudness <= -8.70
# |   |   |   |   |   |   |   |   |--- duration_ms <= 210580.00
# |   |   |   |   |   |   |   |   |   |--- tempo <= 146.21
# |   |   |   |   |   |   |   |   |   |   |--- valence <= 0.23
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- valence >  0.23
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |--- tempo >  146.21
# |   |   |   |   |   |   |   |   |   |   |--- valence <= 0.58
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Rock/Alt/Indie
# |   |   |   |   |   |   |   |   |   |   |--- valence >  0.58
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Country/Folk
# |   |   |   |   |   |   |   |   |--- duration_ms >  210580.00
# |   |   |   |   |   |   |   |   |   |--- instrumentalness <= 0.00
# |   |   |   |   |   |   |   |   |   |   |--- energy <= 0.27
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- energy >  0.27
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |--- instrumentalness >  0.00
# |   |   |   |   |   |   |   |   |   |   |--- acousticness <= 0.76
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- acousticness >  0.76
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |--- loudness >  -8.70
# |   |   |   |   |   |   |   |   |--- acousticness <= 0.53
# |   |   |   |   |   |   |   |   |   |--- duration_ms <= 190893.00
# |   |   |   |   |   |   |   |   |   |   |--- duration_ms <= 141762.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- duration_ms >  141762.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |--- duration_ms >  190893.00
# |   |   |   |   |   |   |   |   |   |   |--- valence <= 0.74
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 11
# |   |   |   |   |   |   |   |   |   |   |--- valence >  0.74
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |--- acousticness >  0.53
# |   |   |   |   |   |   |   |   |   |--- valence <= 0.38
# |   |   |   |   |   |   |   |   |   |   |--- energy <= 0.46
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Country/Folk
# |   |   |   |   |   |   |   |   |   |   |--- energy >  0.46
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |--- valence >  0.38
# |   |   |   |   |   |   |   |   |   |   |--- duration_ms <= 150453.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: R&B/Soul
# |   |   |   |   |   |   |   |   |   |   |--- duration_ms >  150453.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |--- mode_Major >  0.50
# |   |   |   |   |   |   |   |--- loudness <= -9.99
# |   |   |   |   |   |   |   |   |--- speechiness <= 0.03
# |   |   |   |   |   |   |   |   |   |--- key_C <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- duration_ms <= 144313.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- duration_ms >  144313.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |   |--- key_C >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- speechiness <= 0.03
# |   |   |   |   |   |   |   |   |   |   |   |--- class: R&B/Soul
# |   |   |   |   |   |   |   |   |   |   |--- speechiness >  0.03
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |--- speechiness >  0.03
# |   |   |   |   |   |   |   |   |   |--- duration_ms <= 187458.50
# |   |   |   |   |   |   |   |   |   |   |--- popularity <= 36.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- popularity >  36.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |--- duration_ms >  187458.50
# |   |   |   |   |   |   |   |   |   |   |--- duration_ms <= 245365.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |   |--- duration_ms >  245365.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |--- loudness >  -9.99
# |   |   |   |   |   |   |   |   |--- duration_ms <= 297653.50
# |   |   |   |   |   |   |   |   |   |--- acousticness <= 0.59
# |   |   |   |   |   |   |   |   |   |   |--- speechiness <= 0.03
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 13
# |   |   |   |   |   |   |   |   |   |   |--- speechiness >  0.03
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 14
# |   |   |   |   |   |   |   |   |   |--- acousticness >  0.59
# |   |   |   |   |   |   |   |   |   |   |--- duration_ms <= 191233.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |   |--- duration_ms >  191233.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |--- duration_ms >  297653.50
# |   |   |   |   |   |   |   |   |   |--- duration_ms <= 310860.00
# |   |   |   |   |   |   |   |   |   |   |--- energy <= 0.56
# |   |   |   |   |   |   |   |   |   |   |   |--- class: R&B/Soul
# |   |   |   |   |   |   |   |   |   |   |--- energy >  0.56
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- duration_ms >  310860.00
# |   |   |   |   |   |   |   |   |   |   |--- duration_ms <= 377806.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |   |--- duration_ms >  377806.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |--- speechiness >  0.05
# |   |   |   |   |   |   |--- energy <= 0.77
# |   |   |   |   |   |   |   |--- valence <= 0.53
# |   |   |   |   |   |   |   |   |--- acousticness <= 0.71
# |   |   |   |   |   |   |   |   |   |--- popularity <= 37.50
# |   |   |   |   |   |   |   |   |   |   |--- loudness <= -8.05
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |   |--- loudness >  -8.05
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |   |--- popularity >  37.50
# |   |   |   |   |   |   |   |   |   |   |--- instrumentalness <= 0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 10
# |   |   |   |   |   |   |   |   |   |   |--- instrumentalness >  0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |--- acousticness >  0.71
# |   |   |   |   |   |   |   |   |   |--- energy <= 0.40
# |   |   |   |   |   |   |   |   |   |   |--- duration_ms <= 155361.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Country/Folk
# |   |   |   |   |   |   |   |   |   |   |--- duration_ms >  155361.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- energy >  0.40
# |   |   |   |   |   |   |   |   |   |   |--- key_D <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |   |--- key_D >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Country/Folk
# |   |   |   |   |   |   |   |--- valence >  0.53
# |   |   |   |   |   |   |   |   |--- loudness <= -7.25
# |   |   |   |   |   |   |   |   |   |--- liveness <= 0.05
# |   |   |   |   |   |   |   |   |   |   |--- valence <= 0.69
# |   |   |   |   |   |   |   |   |   |   |   |--- class: R&B/Soul
# |   |   |   |   |   |   |   |   |   |   |--- valence >  0.69
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Reggaeton
# |   |   |   |   |   |   |   |   |   |--- liveness >  0.05
# |   |   |   |   |   |   |   |   |   |   |--- valence <= 0.93
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 13
# |   |   |   |   |   |   |   |   |   |   |--- valence >  0.93
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- loudness >  -7.25
# |   |   |   |   |   |   |   |   |   |--- speechiness <= 0.08
# |   |   |   |   |   |   |   |   |   |   |--- key_D <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |   |--- key_D >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- speechiness >  0.08
# |   |   |   |   |   |   |   |   |   |   |--- danceability <= 0.48
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- danceability >  0.48
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |--- energy >  0.77
# |   |   |   |   |   |   |   |--- danceability <= 0.62
# |   |   |   |   |   |   |   |   |--- acousticness <= 0.01
# |   |   |   |   |   |   |   |   |   |--- duration_ms <= 275068.50
# |   |   |   |   |   |   |   |   |   |   |--- mode_Major <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- mode_Major >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |--- duration_ms >  275068.50
# |   |   |   |   |   |   |   |   |   |   |--- danceability <= 0.51
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- danceability >  0.51
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Jazz/Blues
# |   |   |   |   |   |   |   |   |--- acousticness >  0.01
# |   |   |   |   |   |   |   |   |   |--- loudness <= -5.52
# |   |   |   |   |   |   |   |   |   |   |--- tempo <= 146.06
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |   |--- tempo >  146.06
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |--- loudness >  -5.52
# |   |   |   |   |   |   |   |   |   |   |--- speechiness <= 0.06
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |   |--- speechiness >  0.06
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 13
# |   |   |   |   |   |   |   |--- danceability >  0.62
# |   |   |   |   |   |   |   |   |--- tempo <= 171.14
# |   |   |   |   |   |   |   |   |   |--- tempo <= 108.45
# |   |   |   |   |   |   |   |   |   |   |--- acousticness <= 0.04
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- acousticness >  0.04
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- tempo >  108.45
# |   |   |   |   |   |   |   |   |   |   |--- instrumentalness <= 0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- instrumentalness >  0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |--- tempo >  171.14
# |   |   |   |   |   |   |   |   |   |--- loudness <= -6.01
# |   |   |   |   |   |   |   |   |   |   |--- popularity <= 35.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Country/Folk
# |   |   |   |   |   |   |   |   |   |   |--- popularity >  35.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Reggaeton
# |   |   |   |   |   |   |   |   |   |--- loudness >  -6.01
# |   |   |   |   |   |   |   |   |   |   |--- class: Reggaeton
# |   |   |   |--- danceability >  0.67
# |   |   |   |   |--- energy <= 0.56
# |   |   |   |   |   |--- popularity <= 34.50
# |   |   |   |   |   |   |--- speechiness <= 0.08
# |   |   |   |   |   |   |   |--- valence <= 0.36
# |   |   |   |   |   |   |   |   |--- tempo <= 102.47
# |   |   |   |   |   |   |   |   |   |--- loudness <= -5.35
# |   |   |   |   |   |   |   |   |   |   |--- valence <= 0.30
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Jazz/Blues
# |   |   |   |   |   |   |   |   |   |   |--- valence >  0.30
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- loudness >  -5.35
# |   |   |   |   |   |   |   |   |   |   |--- class: R&B/Soul
# |   |   |   |   |   |   |   |   |--- tempo >  102.47
# |   |   |   |   |   |   |   |   |   |--- speechiness <= 0.04
# |   |   |   |   |   |   |   |   |   |   |--- loudness <= -6.93
# |   |   |   |   |   |   |   |   |   |   |   |--- class: R&B/Soul
# |   |   |   |   |   |   |   |   |   |   |--- loudness >  -6.93
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Jazz/Blues
# |   |   |   |   |   |   |   |   |   |--- speechiness >  0.04
# |   |   |   |   |   |   |   |   |   |   |--- instrumentalness <= 0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Reggaeton
# |   |   |   |   |   |   |   |   |   |   |--- instrumentalness >  0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |--- valence >  0.36
# |   |   |   |   |   |   |   |   |--- energy <= 0.44
# |   |   |   |   |   |   |   |   |   |--- danceability <= 0.67
# |   |   |   |   |   |   |   |   |   |   |--- class: Country/Folk
# |   |   |   |   |   |   |   |   |   |--- danceability >  0.67
# |   |   |   |   |   |   |   |   |   |   |--- loudness <= -5.07
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- loudness >  -5.07
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Country/Folk
# |   |   |   |   |   |   |   |   |--- energy >  0.44
# |   |   |   |   |   |   |   |   |   |--- popularity <= 28.50
# |   |   |   |   |   |   |   |   |   |   |--- popularity <= 18.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- popularity >  18.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |--- popularity >  28.50
# |   |   |   |   |   |   |   |   |   |   |--- danceability <= 0.81
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |   |--- danceability >  0.81
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Reggaeton
# |   |   |   |   |   |   |--- speechiness >  0.08
# |   |   |   |   |   |   |   |--- energy <= 0.42
# |   |   |   |   |   |   |   |   |--- valence <= 0.63
# |   |   |   |   |   |   |   |   |   |--- tempo <= 127.44
# |   |   |   |   |   |   |   |   |   |   |--- acousticness <= 0.28
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- acousticness >  0.28
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- tempo >  127.44
# |   |   |   |   |   |   |   |   |   |   |--- speechiness <= 0.28
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Reggaeton
# |   |   |   |   |   |   |   |   |   |   |--- speechiness >  0.28
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- valence >  0.63
# |   |   |   |   |   |   |   |   |   |--- loudness <= -14.94
# |   |   |   |   |   |   |   |   |   |   |--- class: Reggaeton
# |   |   |   |   |   |   |   |   |   |--- loudness >  -14.94
# |   |   |   |   |   |   |   |   |   |   |--- class: Jazz/Blues
# |   |   |   |   |   |   |   |--- energy >  0.42
# |   |   |   |   |   |   |   |   |--- valence <= 0.85
# |   |   |   |   |   |   |   |   |   |--- tempo <= 75.93
# |   |   |   |   |   |   |   |   |   |   |--- class: R&B/Soul
# |   |   |   |   |   |   |   |   |   |--- tempo >  75.93
# |   |   |   |   |   |   |   |   |   |   |--- popularity <= 14.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Rap/Hip-Hop
# |   |   |   |   |   |   |   |   |   |   |--- popularity >  14.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |--- valence >  0.85
# |   |   |   |   |   |   |   |   |   |--- liveness <= 0.07
# |   |   |   |   |   |   |   |   |   |   |--- class: Jazz/Blues
# |   |   |   |   |   |   |   |   |   |--- liveness >  0.07
# |   |   |   |   |   |   |   |   |   |   |--- popularity <= 25.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- popularity >  25.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Reggaeton
# |   |   |   |   |   |--- popularity >  34.50
# |   |   |   |   |   |   |--- speechiness <= 0.03
# |   |   |   |   |   |   |   |--- mode_Minor <= 0.50
# |   |   |   |   |   |   |   |   |--- duration_ms <= 153607.00
# |   |   |   |   |   |   |   |   |   |--- class: R&B/Soul
# |   |   |   |   |   |   |   |   |--- duration_ms >  153607.00
# |   |   |   |   |   |   |   |   |   |--- key_G# <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- energy <= 0.27
# |   |   |   |   |   |   |   |   |   |   |   |--- class: R&B/Soul
# |   |   |   |   |   |   |   |   |   |   |--- energy >  0.27
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |--- key_G# >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: Reggaeton
# |   |   |   |   |   |   |   |--- mode_Minor >  0.50
# |   |   |   |   |   |   |   |   |--- acousticness <= 0.18
# |   |   |   |   |   |   |   |   |   |--- class: R&B/Soul
# |   |   |   |   |   |   |   |   |--- acousticness >  0.18
# |   |   |   |   |   |   |   |   |   |--- class: Jazz/Blues
# |   |   |   |   |   |   |--- speechiness >  0.03
# |   |   |   |   |   |   |   |--- loudness <= -11.38
# |   |   |   |   |   |   |   |   |--- valence <= 0.70
# |   |   |   |   |   |   |   |   |   |--- energy <= 0.22
# |   |   |   |   |   |   |   |   |   |   |--- key_A <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- key_A >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Country/Folk
# |   |   |   |   |   |   |   |   |   |--- energy >  0.22
# |   |   |   |   |   |   |   |   |   |   |--- liveness <= 0.07
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Country/Folk
# |   |   |   |   |   |   |   |   |   |   |--- liveness >  0.07
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |--- valence >  0.70
# |   |   |   |   |   |   |   |   |   |--- duration_ms <= 137653.00
# |   |   |   |   |   |   |   |   |   |   |--- class: R&B/Soul
# |   |   |   |   |   |   |   |   |   |--- duration_ms >  137653.00
# |   |   |   |   |   |   |   |   |   |   |--- danceability <= 0.71
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- danceability >  0.71
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |--- loudness >  -11.38
# |   |   |   |   |   |   |   |   |--- acousticness <= 0.51
# |   |   |   |   |   |   |   |   |   |--- speechiness <= 0.30
# |   |   |   |   |   |   |   |   |   |   |--- valence <= 0.65
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |   |   |--- valence >  0.65
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |--- speechiness >  0.30
# |   |   |   |   |   |   |   |   |   |   |--- energy <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- energy >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- acousticness >  0.51
# |   |   |   |   |   |   |   |   |   |--- liveness <= 0.09
# |   |   |   |   |   |   |   |   |   |   |--- class: Jazz/Blues
# |   |   |   |   |   |   |   |   |   |--- liveness >  0.09
# |   |   |   |   |   |   |   |   |   |   |--- speechiness <= 0.20
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |   |--- speechiness >  0.20
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |--- energy >  0.56
# |   |   |   |   |   |--- popularity <= 35.50
# |   |   |   |   |   |   |--- speechiness <= 0.04
# |   |   |   |   |   |   |   |--- loudness <= -7.31
# |   |   |   |   |   |   |   |   |--- valence <= 0.48
# |   |   |   |   |   |   |   |   |   |--- class: Reggaeton
# |   |   |   |   |   |   |   |   |--- valence >  0.48
# |   |   |   |   |   |   |   |   |   |--- valence <= 0.87
# |   |   |   |   |   |   |   |   |   |   |--- liveness <= 0.08
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- liveness >  0.08
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |--- valence >  0.87
# |   |   |   |   |   |   |   |   |   |   |--- loudness <= -12.12
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- loudness >  -12.12
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |--- loudness >  -7.31
# |   |   |   |   |   |   |   |   |--- instrumentalness <= 0.00
# |   |   |   |   |   |   |   |   |   |--- energy <= 0.79
# |   |   |   |   |   |   |   |   |   |   |--- valence <= 0.96
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 10
# |   |   |   |   |   |   |   |   |   |   |--- valence >  0.96
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- energy >  0.79
# |   |   |   |   |   |   |   |   |   |   |--- speechiness <= 0.03
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- speechiness >  0.03
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |--- instrumentalness >  0.00
# |   |   |   |   |   |   |   |   |   |--- popularity <= 34.50
# |   |   |   |   |   |   |   |   |   |   |--- danceability <= 0.72
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- danceability >  0.72
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- popularity >  34.50
# |   |   |   |   |   |   |   |   |   |   |--- valence <= 0.43
# |   |   |   |   |   |   |   |   |   |   |   |--- class: R&B/Soul
# |   |   |   |   |   |   |   |   |   |   |--- valence >  0.43
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Country/Folk
# |   |   |   |   |   |   |--- speechiness >  0.04
# |   |   |   |   |   |   |   |--- popularity <= 8.50
# |   |   |   |   |   |   |   |   |--- loudness <= -9.06
# |   |   |   |   |   |   |   |   |   |--- class: R&B/Soul
# |   |   |   |   |   |   |   |   |--- loudness >  -9.06
# |   |   |   |   |   |   |   |   |   |--- acousticness <= 0.03
# |   |   |   |   |   |   |   |   |   |   |--- class: R&B/Soul
# |   |   |   |   |   |   |   |   |   |--- acousticness >  0.03
# |   |   |   |   |   |   |   |   |   |   |--- acousticness <= 0.30
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- acousticness >  0.30
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |--- popularity >  8.50
# |   |   |   |   |   |   |   |   |--- acousticness <= 0.58
# |   |   |   |   |   |   |   |   |   |--- energy <= 0.72
# |   |   |   |   |   |   |   |   |   |   |--- instrumentalness <= 0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 14
# |   |   |   |   |   |   |   |   |   |   |--- instrumentalness >  0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 10
# |   |   |   |   |   |   |   |   |   |--- energy >  0.72
# |   |   |   |   |   |   |   |   |   |   |--- danceability <= 0.69
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |   |--- danceability >  0.69
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 12
# |   |   |   |   |   |   |   |   |--- acousticness >  0.58
# |   |   |   |   |   |   |   |   |   |--- duration_ms <= 166217.50
# |   |   |   |   |   |   |   |   |   |   |--- acousticness <= 0.78
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Jazz/Blues
# |   |   |   |   |   |   |   |   |   |   |--- acousticness >  0.78
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- duration_ms >  166217.50
# |   |   |   |   |   |   |   |   |   |   |--- liveness <= 0.41
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |   |--- liveness >  0.41
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |--- popularity >  35.50
# |   |   |   |   |   |   |--- speechiness <= 0.04
# |   |   |   |   |   |   |   |--- danceability <= 0.72
# |   |   |   |   |   |   |   |   |--- duration_ms <= 250486.50
# |   |   |   |   |   |   |   |   |   |--- loudness <= -9.59
# |   |   |   |   |   |   |   |   |   |   |--- duration_ms <= 171566.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Country/Folk
# |   |   |   |   |   |   |   |   |   |   |--- duration_ms >  171566.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Jazz/Blues
# |   |   |   |   |   |   |   |   |   |--- loudness >  -9.59
# |   |   |   |   |   |   |   |   |   |   |--- key_A# <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |   |--- key_A# >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- duration_ms >  250486.50
# |   |   |   |   |   |   |   |   |   |--- tempo <= 121.93
# |   |   |   |   |   |   |   |   |   |   |--- popularity <= 38.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- popularity >  38.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- tempo >  121.93
# |   |   |   |   |   |   |   |   |   |   |--- valence <= 0.21
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Country/Folk
# |   |   |   |   |   |   |   |   |   |   |--- valence >  0.21
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |--- danceability >  0.72
# |   |   |   |   |   |   |   |   |--- loudness <= -7.04
# |   |   |   |   |   |   |   |   |   |--- liveness <= 0.26
# |   |   |   |   |   |   |   |   |   |   |--- acousticness <= 0.41
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- acousticness >  0.41
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Jazz/Blues
# |   |   |   |   |   |   |   |   |   |--- liveness >  0.26
# |   |   |   |   |   |   |   |   |   |   |--- class: R&B/Soul
# |   |   |   |   |   |   |   |   |--- loudness >  -7.04
# |   |   |   |   |   |   |   |   |   |--- speechiness <= 0.03
# |   |   |   |   |   |   |   |   |   |   |--- class: Country/Folk
# |   |   |   |   |   |   |   |   |   |--- speechiness >  0.03
# |   |   |   |   |   |   |   |   |   |   |--- popularity <= 38.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |   |--- popularity >  38.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |--- speechiness >  0.04
# |   |   |   |   |   |   |   |--- duration_ms <= 162516.00
# |   |   |   |   |   |   |   |   |--- loudness <= -10.36
# |   |   |   |   |   |   |   |   |   |--- class: Country/Folk
# |   |   |   |   |   |   |   |   |--- loudness >  -10.36
# |   |   |   |   |   |   |   |   |   |--- acousticness <= 0.02
# |   |   |   |   |   |   |   |   |   |   |--- popularity <= 37.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- popularity >  37.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- acousticness >  0.02
# |   |   |   |   |   |   |   |   |   |   |--- liveness <= 0.15
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- liveness >  0.15
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |--- duration_ms >  162516.00
# |   |   |   |   |   |   |   |   |--- valence <= 0.61
# |   |   |   |   |   |   |   |   |   |--- duration_ms <= 199643.00
# |   |   |   |   |   |   |   |   |   |   |--- tempo <= 101.31
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- tempo >  101.31
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |--- duration_ms >  199643.00
# |   |   |   |   |   |   |   |   |   |   |--- valence <= 0.25
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- valence >  0.25
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 10
# |   |   |   |   |   |   |   |   |--- valence >  0.61
# |   |   |   |   |   |   |   |   |   |--- tempo <= 154.95
# |   |   |   |   |   |   |   |   |   |   |--- tempo <= 100.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 10
# |   |   |   |   |   |   |   |   |   |   |--- tempo >  100.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 11
# |   |   |   |   |   |   |   |   |   |--- tempo >  154.95
# |   |   |   |   |   |   |   |   |   |   |--- tempo <= 192.97
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Reggaeton
# |   |   |   |   |   |   |   |   |   |   |--- tempo >  192.97
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |--- instrumentalness >  0.00
# |   |   |   |--- loudness <= -16.84
# |   |   |   |   |--- danceability <= 0.42
# |   |   |   |   |   |--- danceability <= 0.33
# |   |   |   |   |   |   |--- speechiness <= 0.03
# |   |   |   |   |   |   |   |--- popularity <= 31.00
# |   |   |   |   |   |   |   |   |--- class: Classical/Opera
# |   |   |   |   |   |   |   |--- popularity >  31.00
# |   |   |   |   |   |   |   |   |--- class: Jazz/Blues
# |   |   |   |   |   |   |--- speechiness >  0.03
# |   |   |   |   |   |   |   |--- energy <= 0.25
# |   |   |   |   |   |   |   |   |--- instrumentalness <= 0.97
# |   |   |   |   |   |   |   |   |   |--- tempo <= 62.49
# |   |   |   |   |   |   |   |   |   |   |--- loudness <= -31.57
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Jazz/Blues
# |   |   |   |   |   |   |   |   |   |   |--- loudness >  -31.57
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Classical/Opera
# |   |   |   |   |   |   |   |   |   |--- tempo >  62.49
# |   |   |   |   |   |   |   |   |   |   |--- instrumentalness <= 0.94
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Classical/Opera
# |   |   |   |   |   |   |   |   |   |   |--- instrumentalness >  0.94
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- instrumentalness >  0.97
# |   |   |   |   |   |   |   |   |   |--- key_B <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: Classical/Opera
# |   |   |   |   |   |   |   |   |   |--- key_B >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: Jazz/Blues
# |   |   |   |   |   |   |   |--- energy >  0.25
# |   |   |   |   |   |   |   |   |--- duration_ms <= 68685.00
# |   |   |   |   |   |   |   |   |   |--- class: Jazz/Blues
# |   |   |   |   |   |   |   |   |--- duration_ms >  68685.00
# |   |   |   |   |   |   |   |   |   |--- instrumentalness <= 0.00
# |   |   |   |   |   |   |   |   |   |   |--- class: Jazz/Blues
# |   |   |   |   |   |   |   |   |   |--- instrumentalness >  0.00
# |   |   |   |   |   |   |   |   |   |   |--- tempo <= 162.70
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- tempo >  162.70
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |--- danceability >  0.33
# |   |   |   |   |   |   |--- popularity <= 25.50
# |   |   |   |   |   |   |   |--- acousticness <= 0.41
# |   |   |   |   |   |   |   |   |--- class: Jazz/Blues
# |   |   |   |   |   |   |   |--- acousticness >  0.41
# |   |   |   |   |   |   |   |   |--- liveness <= 0.83
# |   |   |   |   |   |   |   |   |   |--- class: Classical/Opera
# |   |   |   |   |   |   |   |   |--- liveness >  0.83
# |   |   |   |   |   |   |   |   |   |--- class: Jazz/Blues
# |   |   |   |   |   |   |--- popularity >  25.50
# |   |   |   |   |   |   |   |--- energy <= 0.31
# |   |   |   |   |   |   |   |   |--- speechiness <= 0.04
# |   |   |   |   |   |   |   |   |   |--- energy <= 0.09
# |   |   |   |   |   |   |   |   |   |   |--- class: Classical/Opera
# |   |   |   |   |   |   |   |   |   |--- energy >  0.09
# |   |   |   |   |   |   |   |   |   |   |--- speechiness <= 0.03
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- speechiness >  0.03
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Jazz/Blues
# |   |   |   |   |   |   |   |   |--- speechiness >  0.04
# |   |   |   |   |   |   |   |   |   |--- tempo <= 149.13
# |   |   |   |   |   |   |   |   |   |   |--- energy <= 0.05
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Jazz/Blues
# |   |   |   |   |   |   |   |   |   |   |--- energy >  0.05
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- tempo >  149.13
# |   |   |   |   |   |   |   |   |   |   |--- loudness <= -17.51
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Jazz/Blues
# |   |   |   |   |   |   |   |   |   |   |--- loudness >  -17.51
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Country/Folk
# |   |   |   |   |   |   |   |--- energy >  0.31
# |   |   |   |   |   |   |   |   |--- valence <= 0.62
# |   |   |   |   |   |   |   |   |   |--- class: Jazz/Blues
# |   |   |   |   |   |   |   |   |--- valence >  0.62
# |   |   |   |   |   |   |   |   |   |--- class: Classical/Opera
# |   |   |   |   |--- danceability >  0.42
# |   |   |   |   |   |--- popularity <= 27.50
# |   |   |   |   |   |   |--- liveness <= 0.12
# |   |   |   |   |   |   |   |--- danceability <= 0.49
# |   |   |   |   |   |   |   |   |--- acousticness <= 0.63
# |   |   |   |   |   |   |   |   |   |--- class: Jazz/Blues
# |   |   |   |   |   |   |   |   |--- acousticness >  0.63
# |   |   |   |   |   |   |   |   |   |--- class: Classical/Opera
# |   |   |   |   |   |   |   |--- danceability >  0.49
# |   |   |   |   |   |   |   |   |--- liveness <= 0.09
# |   |   |   |   |   |   |   |   |   |--- duration_ms <= 213186.50
# |   |   |   |   |   |   |   |   |   |   |--- class: Classical/Opera
# |   |   |   |   |   |   |   |   |   |--- duration_ms >  213186.50
# |   |   |   |   |   |   |   |   |   |   |--- instrumentalness <= 0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: R&B/Soul
# |   |   |   |   |   |   |   |   |   |   |--- instrumentalness >  0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- liveness >  0.09
# |   |   |   |   |   |   |   |   |   |--- speechiness <= 0.03
# |   |   |   |   |   |   |   |   |   |   |--- class: Classical/Opera
# |   |   |   |   |   |   |   |   |   |--- speechiness >  0.03
# |   |   |   |   |   |   |   |   |   |   |--- class: Jazz/Blues
# |   |   |   |   |   |   |--- liveness >  0.12
# |   |   |   |   |   |   |   |--- danceability <= 0.69
# |   |   |   |   |   |   |   |   |--- duration_ms <= 33900.00
# |   |   |   |   |   |   |   |   |   |--- class: Rock/Alt/Indie
# |   |   |   |   |   |   |   |   |--- duration_ms >  33900.00
# ...
# |   |   |   |   |   |   |   |   |   |   |--- key_G# >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- valence >  0.29
# |   |   |   |   |   |   |   |   |   |--- loudness <= -13.88
# |   |   |   |   |   |   |   |   |   |   |--- valence <= 0.78
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- valence >  0.78
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Classical/Opera
# |   |   |   |   |   |   |   |   |   |--- loudness >  -13.88
# |   |   |   |   |   |   |   |   |   |   |--- tempo <= 88.87
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- tempo >  88.87
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |--- speechiness >  0.07
# |   |   |   |   |   |   |   |--- danceability <= 0.55
# |   |   |   |   |   |   |   |   |--- danceability <= 0.52
# |   |   |   |   |   |   |   |   |   |--- danceability <= 0.46
# |   |   |   |   |   |   |   |   |   |   |--- speechiness <= 0.09
# |   |   |   |   |   |   |   |   |   |   |   |--- class: R&B/Soul
# |   |   |   |   |   |   |   |   |   |   |--- speechiness >  0.09
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- danceability >  0.46
# |   |   |   |   |   |   |   |   |   |   |--- class: Rock/Alt/Indie
# |   |   |   |   |   |   |   |   |--- danceability >  0.52
# |   |   |   |   |   |   |   |   |   |--- key_G# <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: Jazz/Blues
# |   |   |   |   |   |   |   |   |   |--- key_G# >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: Rap/Hip-Hop
# |   |   |   |   |   |   |   |--- danceability >  0.55
# |   |   |   |   |   |   |   |   |--- acousticness <= 0.94
# |   |   |   |   |   |   |   |   |   |--- class: R&B/Soul
# |   |   |   |   |   |   |   |   |--- acousticness >  0.94
# |   |   |   |   |   |   |   |   |   |--- class: Jazz/Blues
# |   |   |   |   |   |--- popularity >  60.50
# |   |   |   |   |   |   |--- speechiness <= 0.04
# |   |   |   |   |   |   |   |--- duration_ms <= 253523.50
# |   |   |   |   |   |   |   |   |--- key_D <= 0.50
# |   |   |   |   |   |   |   |   |   |--- tempo <= 98.33
# |   |   |   |   |   |   |   |   |   |   |--- energy <= 0.22
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- energy >  0.22
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- tempo >  98.33
# |   |   |   |   |   |   |   |   |   |   |--- loudness <= -13.74
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Country/Folk
# |   |   |   |   |   |   |   |   |   |   |--- loudness >  -13.74
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |--- key_D >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: Rock/Alt/Indie
# |   |   |   |   |   |   |   |--- duration_ms >  253523.50
# |   |   |   |   |   |   |   |   |--- acousticness <= 0.92
# |   |   |   |   |   |   |   |   |   |--- liveness <= 0.11
# |   |   |   |   |   |   |   |   |   |   |--- class: Rock/Alt/Indie
# |   |   |   |   |   |   |   |   |   |--- liveness >  0.11
# |   |   |   |   |   |   |   |   |   |   |--- popularity <= 63.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: R&B/Soul
# |   |   |   |   |   |   |   |   |   |   |--- popularity >  63.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Pop
# |   |   |   |   |   |   |   |   |--- acousticness >  0.92
# |   |   |   |   |   |   |   |   |   |--- speechiness <= 0.04
# |   |   |   |   |   |   |   |   |   |   |--- class: Jazz/Blues
# |   |   |   |   |   |   |   |   |   |--- speechiness >  0.04
# |   |   |   |   |   |   |   |   |   |   |--- class: R&B/Soul
# |   |   |   |   |   |   |--- speechiness >  0.04
# |   |   |   |   |   |   |   |--- speechiness <= 0.05
# |   |   |   |   |   |   |   |   |--- energy <= 0.28
# |   |   |   |   |   |   |   |   |   |--- danceability <= 0.44
# |   |   |   |   |   |   |   |   |   |   |--- class: Pop
# |   |   |   |   |   |   |   |   |   |--- danceability >  0.44
# |   |   |   |   |   |   |   |   |   |   |--- loudness <= -10.82
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- loudness >  -10.82
# |   |   |   |   |   |   |   |   |   |   |   |--- class: R&B/Soul
# |   |   |   |   |   |   |   |   |--- energy >  0.28
# |   |   |   |   |   |   |   |   |   |--- class: Pop
# |   |   |   |   |   |   |   |--- speechiness >  0.05
# |   |   |   |   |   |   |   |   |--- speechiness <= 0.18
# |   |   |   |   |   |   |   |   |   |--- liveness <= 0.16
# |   |   |   |   |   |   |   |   |   |   |--- popularity <= 69.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- popularity >  69.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Pop
# |   |   |   |   |   |   |   |   |   |--- liveness >  0.16
# |   |   |   |   |   |   |   |   |   |   |--- loudness <= -12.92
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- loudness >  -12.92
# |   |   |   |   |   |   |   |   |   |   |   |--- class: R&B/Soul
# |   |   |   |   |   |   |   |   |--- speechiness >  0.18
# |   |   |   |   |   |   |   |   |   |--- popularity <= 70.50
# |   |   |   |   |   |   |   |   |   |   |--- instrumentalness <= 0.01
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Rap/Hip-Hop
# |   |   |   |   |   |   |   |   |   |   |--- instrumentalness >  0.01
# |   |   |   |   |   |   |   |   |   |   |   |--- class: R&B/Soul
# |   |   |   |   |   |   |   |   |   |--- popularity >  70.50
# |   |   |   |   |   |   |   |   |   |   |--- class: Pop
# |   |   |   |--- instrumentalness >  0.49
# |   |   |   |   |--- danceability <= 0.37
# |   |   |   |   |   |--- danceability <= 0.24
# |   |   |   |   |   |   |--- popularity <= 48.50
# |   |   |   |   |   |   |   |--- duration_ms <= 57933.50
# |   |   |   |   |   |   |   |   |--- class: Country/Folk
# |   |   |   |   |   |   |   |--- duration_ms >  57933.50
# |   |   |   |   |   |   |   |   |--- speechiness <= 0.12
# |   |   |   |   |   |   |   |   |   |--- energy <= 0.29
# |   |   |   |   |   |   |   |   |   |   |--- class: Classical/Opera
# |   |   |   |   |   |   |   |   |   |--- energy >  0.29
# |   |   |   |   |   |   |   |   |   |   |--- popularity <= 45.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Classical/Opera
# |   |   |   |   |   |   |   |   |   |   |--- popularity >  45.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- speechiness >  0.12
# |   |   |   |   |   |   |   |   |   |--- class: Jazz/Blues
# |   |   |   |   |   |   |--- popularity >  48.50
# |   |   |   |   |   |   |   |--- liveness <= 0.17
# |   |   |   |   |   |   |   |   |--- key_F <= 0.50
# |   |   |   |   |   |   |   |   |   |--- energy <= 0.06
# |   |   |   |   |   |   |   |   |   |   |--- class: Country/Folk
# |   |   |   |   |   |   |   |   |   |--- energy >  0.06
# |   |   |   |   |   |   |   |   |   |   |--- class: Classical/Opera
# |   |   |   |   |   |   |   |   |--- key_F >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: Rock/Alt/Indie
# |   |   |   |   |   |   |   |--- liveness >  0.17
# |   |   |   |   |   |   |   |   |--- time_signature_3/4 <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: Rock/Alt/Indie
# |   |   |   |   |   |   |   |   |--- time_signature_3/4 >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: Country/Folk
# |   |   |   |   |   |--- danceability >  0.24
# |   |   |   |   |   |   |--- energy <= 0.08
# |   |   |   |   |   |   |   |--- danceability <= 0.34
# |   |   |   |   |   |   |   |   |--- class: Jazz/Blues
# |   |   |   |   |   |   |   |--- danceability >  0.34
# |   |   |   |   |   |   |   |   |--- speechiness <= 0.03
# |   |   |   |   |   |   |   |   |   |--- class: Rock/Alt/Indie
# |   |   |   |   |   |   |   |   |--- speechiness >  0.03
# |   |   |   |   |   |   |   |   |   |--- class: Classical/Opera
# |   |   |   |   |   |   |--- energy >  0.08
# |   |   |   |   |   |   |   |--- key_B <= 0.50
# |   |   |   |   |   |   |   |   |--- duration_ms <= 427920.00
# |   |   |   |   |   |   |   |   |   |--- valence <= 0.23
# |   |   |   |   |   |   |   |   |   |   |--- loudness <= -16.54
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- loudness >  -16.54
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |--- valence >  0.23
# |   |   |   |   |   |   |   |   |   |   |--- tempo <= 73.46
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Jazz/Blues
# |   |   |   |   |   |   |   |   |   |   |--- tempo >  73.46
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |--- duration_ms >  427920.00
# |   |   |   |   |   |   |   |   |   |--- speechiness <= 0.03
# |   |   |   |   |   |   |   |   |   |   |--- class: Jazz/Blues
# |   |   |   |   |   |   |   |   |   |--- speechiness >  0.03
# |   |   |   |   |   |   |   |   |   |   |--- liveness <= 0.70
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- liveness >  0.70
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Jazz/Blues
# |   |   |   |   |   |   |   |--- key_B >  0.50
# |   |   |   |   |   |   |   |   |--- speechiness <= 0.04
# |   |   |   |   |   |   |   |   |   |--- class: Jazz/Blues
# |   |   |   |   |   |   |   |   |--- speechiness >  0.04
# |   |   |   |   |   |   |   |   |   |--- loudness <= -13.42
# |   |   |   |   |   |   |   |   |   |   |--- class: Country/Folk
# |   |   |   |   |   |   |   |   |   |--- loudness >  -13.42
# |   |   |   |   |   |   |   |   |   |   |--- tempo <= 79.98
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Jazz/Blues
# |   |   |   |   |   |   |   |   |   |   |--- tempo >  79.98
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Rock/Alt/Indie
# |   |   |   |   |--- danceability >  0.37
# |   |   |   |   |   |--- danceability <= 0.61
# |   |   |   |   |   |   |--- duration_ms <= 328572.50
# |   |   |   |   |   |   |   |--- key_E <= 0.50
# |   |   |   |   |   |   |   |   |--- key_D <= 0.50
# |   |   |   |   |   |   |   |   |   |--- duration_ms <= 143900.00
# |   |   |   |   |   |   |   |   |   |   |--- loudness <= -14.49
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- loudness >  -14.49
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- duration_ms >  143900.00
# |   |   |   |   |   |   |   |   |   |   |--- speechiness <= 0.03
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- speechiness >  0.03
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 11
# |   |   |   |   |   |   |   |   |--- key_D >  0.50
# |   |   |   |   |   |   |   |   |   |--- valence <= 0.09
# |   |   |   |   |   |   |   |   |   |   |--- duration_ms <= 283900.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Country/Folk
# |   |   |   |   |   |   |   |   |   |   |--- duration_ms >  283900.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Jazz/Blues
# |   |   |   |   |   |   |   |   |   |--- valence >  0.09
# |   |   |   |   |   |   |   |   |   |   |--- loudness <= -11.16
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- loudness >  -11.16
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Jazz/Blues
# |   |   |   |   |   |   |   |--- key_E >  0.50
# |   |   |   |   |   |   |   |   |--- popularity <= 39.50
# |   |   |   |   |   |   |   |   |   |--- class: Classical/Opera
# |   |   |   |   |   |   |   |   |--- popularity >  39.50
# |   |   |   |   |   |   |   |   |   |--- valence <= 0.38
# |   |   |   |   |   |   |   |   |   |   |--- liveness <= 0.11
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- liveness >  0.11
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Country/Folk
# |   |   |   |   |   |   |   |   |   |--- valence >  0.38
# |   |   |   |   |   |   |   |   |   |   |--- class: Classical/Opera
# |   |   |   |   |   |   |--- duration_ms >  328572.50
# |   |   |   |   |   |   |   |--- acousticness <= 0.99
# |   |   |   |   |   |   |   |   |--- loudness <= -10.11
# |   |   |   |   |   |   |   |   |   |--- duration_ms <= 671693.00
# |   |   |   |   |   |   |   |   |   |   |--- time_signature_4/4 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- time_signature_4/4 >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Jazz/Blues
# |   |   |   |   |   |   |   |   |   |--- duration_ms >  671693.00
# |   |   |   |   |   |   |   |   |   |   |--- duration_ms <= 775520.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Classical/Opera
# |   |   |   |   |   |   |   |   |   |   |--- duration_ms >  775520.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Jazz/Blues
# |   |   |   |   |   |   |   |   |--- loudness >  -10.11
# |   |   |   |   |   |   |   |   |   |--- energy <= 0.48
# |   |   |   |   |   |   |   |   |   |   |--- class: Country/Folk
# |   |   |   |   |   |   |   |   |   |--- energy >  0.48
# |   |   |   |   |   |   |   |   |   |   |--- class: Jazz/Blues
# |   |   |   |   |   |   |   |--- acousticness >  0.99
# |   |   |   |   |   |   |   |   |--- class: Classical/Opera
# |   |   |   |   |   |--- danceability >  0.61
# |   |   |   |   |   |   |--- valence <= 0.19
# |   |   |   |   |   |   |   |--- instrumentalness <= 0.92
# |   |   |   |   |   |   |   |   |--- class: Rock/Alt/Indie
# |   |   |   |   |   |   |   |--- instrumentalness >  0.92
# |   |   |   |   |   |   |   |   |--- class: Classical/Opera
# |   |   |   |   |   |   |--- valence >  0.19
# |   |   |   |   |   |   |   |--- instrumentalness <= 0.57
# |   |   |   |   |   |   |   |   |--- popularity <= 43.00
# |   |   |   |   |   |   |   |   |   |--- class: Jazz/Blues
# |   |   |   |   |   |   |   |   |--- popularity >  43.00
# |   |   |   |   |   |   |   |   |   |--- class: Rock/Alt/Indie
# |   |   |   |   |   |   |   |--- instrumentalness >  0.57
# |   |   |   |   |   |   |   |   |--- acousticness <= 0.93
# |   |   |   |   |   |   |   |   |   |--- energy <= 0.10
# |   |   |   |   |   |   |   |   |   |   |--- class: Rock/Alt/Indie
# |   |   |   |   |   |   |   |   |   |--- energy >  0.10
# |   |   |   |   |   |   |   |   |   |   |--- class: Jazz/Blues
# |   |   |   |   |   |   |   |   |--- acousticness >  0.93
# |   |   |   |   |   |   |   |   |   |--- time_signature_4/4 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- valence <= 0.38
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- valence >  0.38
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Classical/Opera
# |   |   |   |   |   |   |   |   |   |--- time_signature_4/4 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- duration_ms <= 155400.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- duration_ms >  155400.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# C:\Users\Ce\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:143: FutureWarning: The sklearn.tree.export module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.tree. Anything that cannot be imported from sklearn.tree is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %% [markdown]
# ### Test 3: Decision Tree with Feature Selection

# %%
from sklearn.feature_selection import VarianceThreshold

# %%
sel = VarianceThreshold(threshold=(.8 * (1 - .8)))
X3 = sel.fit_transform(X)

# %%
X3_train, X3_test, y3_train, y3_test = train_test_split(X3, y, test_size=0.3, random_state = 7)

# %%
Model3 = DecisionTreeClassifier()
Model3.fit(X3_train,y3_train)
Predict3 = Model3.predict(X3_test)

print(classification_report(y3_test,Predict3))
# Out:
#                  precision    recall  f1-score   support
#
# Classical/Opera       0.84      0.83      0.83      5085
#    Country/Folk       0.32      0.33      0.33      3396
#      Jazz/Blues       0.45      0.44      0.45      4624
#             Pop       0.43      0.43      0.43       836
#        R&B/Soul       0.21      0.22      0.22      2834
#     Rap/Hip-Hop       0.31      0.30      0.31      1896
#       Reggaeton       0.39      0.40      0.40      2572
#  Rock/Alt/Indie       0.31      0.30      0.30      3441
#
#        accuracy                           0.45     24684
#       macro avg       0.41      0.41      0.41     24684
#    weighted avg       0.45      0.45      0.45     24684

# %%
f_list = list(sel.get_support(indices=True))

# %%
for item in f_list:
    print(X.columns[item])
# Out:
# popularity
# duration_ms
# loudness
# tempo
# mode_Major
# mode_Minor

# %%
list(Model3.feature_importances_)
# Out:
# [0.20924807653961158,
#  0.21264359169458313,
#  0.35481715614037895,
#  0.2060900571934613,
#  0.0065891703372506095,
#  0.010611948094714488]

# %% [markdown]
# ### Test 4: Set parameters for the Decision Tree

# %%
X4_train, X4_test, y4_train, y4_test = train_test_split(X, y, test_size=0.3, stratify = y, random_state = 9)

# %%
Model4 = DecisionTreeClassifier(criterion = 'entropy', max_depth=10, min_samples_leaf=100)
Model4.fit(X4_train,y4_train)
Predict4 = Model4.predict(X4_test)

print(classification_report(y4_test,Predict4))
# Out:
#                  precision    recall  f1-score   support
#
# Classical/Opera       0.93      0.90      0.91      5114
#    Country/Folk       0.50      0.61      0.55      3406
#      Jazz/Blues       0.65      0.65      0.65      4658
#             Pop       0.50      0.54      0.52       835
#        R&B/Soul       0.44      0.35      0.39      2843
#     Rap/Hip-Hop       0.61      0.68      0.64      1859
#       Reggaeton       0.70      0.61      0.65      2561
#  Rock/Alt/Indie       0.55      0.55      0.55      3408
#
#        accuracy                           0.64     24684
#       macro avg       0.61      0.61      0.61     24684
#    weighted avg       0.64      0.64      0.64     24684

# %%
print("Number of levels: ", Model4.get_depth())
print("Number of leaves: ", Model4.get_n_leaves())
print("Parameters: ", Model4.get_params())
# Out:
# Number of levels:  10
# Number of leaves:  294
# Parameters:  {'ccp_alpha': 0.0, 'class_weight': None, 'criterion': 'entropy', 'max_depth': 10, 'max_features': None, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.0, 'min_impurity_split': None, 'min_samples_leaf': 100, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'presort': 'deprecated', 'random_state': None, 'splitter': 'best'}
